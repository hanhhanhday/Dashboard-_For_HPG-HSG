# %% [markdown]
# # crawl Befood

# %%
import requests
import json

def get_home_collections(latitude=10.77253621500006, longitude=106.69798153800008):
    url = "https://gw.be.com.vn/api/v1/be-merchant-gateway/web/customer/get_home_collections"

    payload = json.dumps({
    "latitude": latitude,
    "longitude": longitude
    })
    headers = {
    'authorization': 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjowLCJhdWQiOiJndWVzdCIsImV4cCI6MTc0NTQyMDkwNCwiaWF0IjoxNzQ1MzM0NTA0LCJpc3MiOiJiZS1kZWxpdmVyeS1nYXRld2F5In0.5hJHaOcSB3lq9UP8ImrSV_yI57Z-wZdmNbtNm693a_M',
    'content-type': 'application/json',
    }

    response = requests.request("POST", url, headers=headers, data=payload)

    return json.loads(response.text)

def get_restaurants(collection_id=763, page=1, limit=100,latitude=10.77253621500006,longitude=106.69798153800008):

  url = "https://gw.be.com.vn/api/v1/be-marketplace/web/collection/items/restaurants"

  payload = json.dumps({
    "collection_id": f"{collection_id}",
    "page": page,
    "limit": limit,
    "latitude": latitude,
    "longitude": longitude
  })
  headers = {
    'authorization': 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjowLCJhdWQiOiJndWVzdCIsImV4cCI6MTc0ODM1NzI1MSwiaWF0IjoxNzQ4MjcwODUxLCJpc3MiOiJiZS1kZWxpdmVyeS1nYXRld2F5In0.udjZK2f9krF6Vrd6NB02KaHsZN_fTheuL1EXMYCSkQY',
    'content-type': 'application/json'
  }

  response = requests.request("POST", url, headers=headers, data=payload)

  return json.loads(response.text)



def get_detail(restaurant_id=21435, latitude=10, longitude=106):
  url = "https://gw.be.com.vn/api/v1/be-marketplace/web/restaurant/detail"

  payload = json.dumps({
    "restaurant_id": f"{restaurant_id}",
    "latitude": latitude,
    "longitude": longitude
  })
  headers = {
    'authorization': 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjowLCJhdWQiOiJndWVzdCIsImV4cCI6MTc0ODM1NzI1MSwiaWF0IjoxNzQ4MjcwODUxLCJpc3MiOiJiZS1kZWxpdmVyeS1nYXRld2F5In0.udjZK2f9krF6Vrd6NB02KaHsZN_fTheuL1EXMYCSkQY',
    'content-type': 'application/json'
  }

  response = requests.request("POST", url, headers=headers, data=payload)

  return json.loads(response.text)

# %%
latitude=10.77253621500006
longitude=106.69798153800008

# Lấy collections ids
collection_ids = get_home_collections(latitude=latitude, longitude=longitude)

for data_ids in collection_ids['collections']:
    print(f"=== Start crawler ID: {data_ids['id']} --- Name: {data_ids['name']} ===")
    
    for page_id in range(1, 1001):
        restaurant_data = get_restaurants(collection_id=data_ids['id'], page=page_id, latitude=latitude, longitude=longitude)
        for restaurant in restaurant_data['data']:
            print("Name: ", restaurant['name'])
            print("Address: ", restaurant['address'])
            print("Restaurant_id: ", restaurant['restaurant_id'])
            restaurant_detail = get_detail(restaurant_id=restaurant['restaurant_id'], latitude=latitude, longitude=longitude)
            # print(restaurant_detail)
            for i, detail in enumerate(restaurant_detail['data']['categories']):
                print("Mon so:", i+1)
                print("Name: ", detail['category_name'])
                for item in detail['items']:
                    print("Item name: ", item['item_name'], ", Item price: ", item['display_price'])
                break
            break
        break 
    print(f"=== End crawler ID: {data_ids['id']} --- Name: {data_ids['name']} ===")
    print()
# Out:
# === Start crawler ID: 763 --- Name: Bún Phở ===
# Name:  Hủ Tiếu Nam Vang, Mì & Nui Bò Hải Sản Anh Tuấn - Lê Công Kiều
# Address:  80 Lê Công Kiều, Phường Nguyễn Thái Bình, Quận 1, Hồ Chí Minh
# Restaurant_id:  93587
# Mon so: 1
# Name:  Món Nước
# Item name:  Hủ tiếu thập cẩm , Item price:  65.000
# Item name:  Hủ tiếu tôm , Item price:  70.000
# Item name:  Hủ tiếu mực , Item price:  65.000
# Item name:  Hủ tiếu bò , Item price:  65.000
# Item name:  Hủ tiếu đồ lòng , Item price:  65.000
# Item name:  Hủ tiếu xương , Item price:  65.000
# Item name:  Mì thập cẩm , Item price:  65.000
# Item name:  Mì tôm , Item price:  70.000
# Item name:  Mì bò , Item price:  65.000
# Item name:  Mì xương , Item price:  65.000
# Item name:  Nui thập cẩm , Item price:  65.000
# Item name:  Nui tôm , Item price:  70.000
# Item name:  Nui bò , Item price:  65.000
# Item name:  Nui xương , Item price:  65.000
# Item name:  Bánh canh thập cẩm , Item price:  65.000
# ...
